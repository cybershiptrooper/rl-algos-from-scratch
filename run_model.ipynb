# %%
from utils import make_model, make_env, plot_rewards, seed_everything, device
from utils.hyperparams import *

# %%
env = make_env("cartpole")
seed_everything(env)
model = make_model("a2c", env)
config = Base_Config({
    # edit config here
})
rewards, losses = model.train(env)
plot_rewards(rewards)
env.close()
# Out:
#   5%|▌         | 27/500 [00:00<00:01, 268.09it/s]
# No parameters found, using cpu
#  21%|██        | 103/500 [00:00<00:03, 115.11it/s]
# Episode 100
# Mean Reward for last 100 episodess 45.03
#  41%|████      | 204/500 [00:04<00:11, 26.41it/s]
# Episode 200
# Mean Reward for last 100 episodess 301.99
#  61%|██████    | 303/500 [00:10<00:08, 22.63it/s]
# Episode 300
# Mean Reward for last 100 episodess 464.95
#  80%|████████  | 402/500 [00:16<00:06, 14.04it/s]
# Episode 400
# Mean Reward for last 100 episodess 450.45
# 100%|██████████| 500/500 [00:23<00:00, 21.56it/s]
# Episode 500
# Mean Reward for last 100 episodess 500.00
