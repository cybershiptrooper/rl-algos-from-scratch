# %%
import argparse
from utils import make_model, make_env, plot_rewards, seed_everything, device
from utils.hyperparams import *

# %%
env = make_env("cartpole")
seed_everything(env)
model = make_model("reinforce", env)
config = Base_Config({
    # edit config here
})
rewards, losses = model.train(env)
plot_rewards(rewards)
env.close()
# Out:
#  12%|█▏        | 160/1300 [00:00<00:03, 373.95it/s]
# Episode:  100 Mean Reward for last 100 episodes:  239.6314104356265
#  18%|█▊        | 234/1300 [00:00<00:03, 345.00it/s]
# Episode:  200 Mean Reward for last 100 episodes:  378.62016043901707
#  26%|██▌       | 333/1300 [00:01<00:03, 267.39it/s]
# Episode:  300 Mean Reward for last 100 episodes:  572.776059687392
#  34%|███▎      | 438/1300 [00:01<00:03, 237.10it/s]
# Episode:  400 Mean Reward for last 100 episodes:  914.2776274240965
#  40%|████      | 524/1300 [00:02<00:04, 169.95it/s]
# Episode:  500 Mean Reward for last 100 episodes:  1387.136268919351
#  47%|████▋     | 615/1300 [00:02<00:06, 108.48it/s]
# Episode:  600 Mean Reward for last 100 episodes:  2980.2643562108397
#  54%|█████▍    | 707/1300 [00:04<00:08, 66.71it/s]
# Episode:  700 Mean Reward for last 100 episodes:  6503.527796441574
#  62%|██████▏   | 806/1300 [00:05<00:08, 60.08it/s]
# Episode:  800 Mean Reward for last 100 episodes:  8178.810350772543
#  70%|███████   | 910/1300 [00:07<00:06, 58.12it/s]
# Episode:  900 Mean Reward for last 100 episodes:  11205.120845734475
#  77%|███████▋  | 1006/1300 [00:10<00:06, 45.06it/s]
# Episode:  1000 Mean Reward for last 100 episodes:  16277.943089698556
#  85%|████████▍ | 1103/1300 [00:13<00:06, 32.01it/s]
# Episode:  1100 Mean Reward for last 100 episodes:  18502.88359338886
#  93%|█████████▎| 1204/1300 [00:17<00:03, 24.81it/s]
# Episode:  1200 Mean Reward for last 100 episodes:  32998.03800234685
# 100%|██████████| 1300/1300 [00:22<00:00, 57.54it/s]
# Episode:  1300 Mean Reward for last 100 episodes:  43228.55610676826
